# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import xgboost as xgb
import seaborn as sns
#from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import Normalizer

# %%
data = pd.read_csv("train.csv")

# %% [markdown]
# ## Correlation Matrix

# %%
# Compute the correlation matrix
corr = data.corr()

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
unwanted_colums = data.columns[data.columns.str.startswith('ps_calc_')]
data = data.drop(unwanted_colums, axis = 1)

bin_cols = [col for col in data if col.endswith('bin')]
cat_cols = [col for col in data if col.endswith('cat')]

data = pd.get_dummies(data, columns=cat_cols, drop_first=True)
Ydata = data["target"].as_matrix()
Xdata = data.drop(["target", "id"], axis=1).as_matrix()
del data

# %% [markdown]
# Stratified Kfold

# %%
kfold = 5
skf = StratifiedKFold(n_splits=kfold, random_state=42)

# %% [markdown]
# XGBoost params

# %%
params = {
    'min_child_weight': 10.0,
    'objective': 'binary:logistic',
    'max_depth': 7,
    'max_delta_step': 1.8,
    'colsample_bytree': 0.4,
    'subsample': 0.8,
    'eta': 0.025,
    'gamma': 0.65,
    'num_boost_round' : 700
    }

# %% [markdown]
# Gini Metrics

# %%
def gini(actual, pred, cmpcol = 0, sortcol = 1):
    assert( len(actual) == len(pred) )
    all = np.asarray(np.c_[ actual, pred, np.arange(len(actual)) ], dtype=np.float)
    all = all[ np.lexsort((all[:,2], -1*all[:,1])) ]
    totalLosses = all[:,0].sum()
    giniSum = all[:,0].cumsum().sum() / totalLosses
    
    giniSum -= (len(actual) + 1) / 2.
    return giniSum / len(actual)
 
def gini_normalized(a, p):
    return gini(a, p) / gini(a, a)

def gini_xgb(preds, dtrain):
    labels = dtrain.get_label()
    gini_score = gini_normalized(labels, preds)
    return 'gini', gini_score

# %% [markdown]
# training

# %%
d_train = xgb.DMatrix(Xdata, Ydata)
del Xdata
del Ydata

# %%
mdl = xgb.train(params, d_train, 1600, early_stopping_rounds=70, maximize=True, verbose_eval=100)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-4b205abe1ce3> in <module>()
# ----> 1 mdl = xgb.train(params, d_train, 1600, early_stopping_rounds=70, maximize=True, verbose_eval=100)
#
# /home/jose/anaconda3/lib/python3.6/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, learning_rates, xgb_model, callbacks)
#     203                            evals=evals,
#     204                            obj=obj, feval=feval,
# --> 205                            xgb_model=xgb_model, callbacks=callbacks)
#     206
#     207
#
# /home/jose/anaconda3/lib/python3.6/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      99                                end_iteration=num_boost_round,
# ...

# %% [markdown]
# Scale data

# %%
scaler = Normalizer()
scaler.fit(Xdata)
Xdata = scaler.transform(Xdata)

# %%
clf = LogisticRegression(C = 100)

# %%
clf.fit(Xdata, Ydata)
# Out:
# LogisticRegression(C=100, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
del Xdata

# %%
testdata = pd.read_csv("test.csv")
testdata = pd.get_dummies(testdata, columns=cat_cols, drop_first=True)
Xtestdata = testdata.drop(["id"], axis=1).as_matrix()
del testdata

# %%
Xtestdata = scaler.transform(Xtestdata)

# %%
preds = clf.predict(Xtestdata)

# %%
np.sum(preds)
# Out:
# 2
